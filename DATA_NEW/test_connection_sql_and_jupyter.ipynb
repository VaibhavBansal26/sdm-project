# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

# %%
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      'SERVER=LAPTOP-IIJ7QF0R ;'
                      'DATABASE=master;'
                      'Trusted_Connection=yes;')

# %%
import pandas as pd

# Sample query
query = "SELECT top 10 * FROM SalesData"
df = pd.read_sql(query, cnxn)
df.head(10)  # Displays the first five rows of the DataFrame
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...

# %%
query = "SELECT top 10 * FROM new_SalesData_1"
df = pd.read_sql(query, cnxn)
df.head(10)
# Out:
#   InvoiceNo StockCode                     Description  Quantity  \
# 0    558484     23298                  SPOTTY BUNTING         6
# 1    558484     22423        REGENCY CAKESTAND 3 TIER         6
# 2    558484     23245      SET OF 3 REGENCY CAKE TINS         8
# 3    558484     22956        36 FOIL HEART CAKE CASES         6
# 4    558484     21164     HOME SWEET HOME METAL SIGN          6
# 5   C548471     22776     SWEETHEART CAKESTAND 3 TIER        -1
# 6   C549913     22961          JAM MAKING SET PRINTED       -12
# 7   C559495     23288       GREEN VINTAGE SPOT BEAKER        -1
# 8   C559495     23245      SET OF 3 REGENCY CAKE TINS        -1
# 9   C559742     22989  SET 2 PANTRY DESIGN TEA TOWELS        -6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Gender  Age  \
# 0 2011-06-30 10:09:00       4.95       14267  United Kingdom  Female   17
# 1 2011-06-30 10:09:00      12.75       14267  United Kingdom  Female   17
# ...
